# %% [markdown]
# <a href="https://colab.research.google.com/github/rgrandym/data_science_cambridge/blob/main/CAM_DS_C301_9_1_Topic_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/rgrandym/data_science_cambridge/blob/main/CAM_DS_C301_9_1_Topic_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **First things first** - please go to 'File' and select 'Save a copy in Drive' so that you have your own version of this activity set up and ready to use.
# Remember to update the portfolio index link to your own work once completed!

# %% [markdown]
# # Topic project 9.1 Using time series analysis for sales and demand forecasting
#
# **Welcome to your topic project: Using time series analysis for sales and demand forecasting**
#
# In this project, you will bridge the gap between theory and practical application by utilising time series analysis techniques to forecast sales and demand. Forecasting involves analysing historical sales data to accurately predict future sales trends and demand patterns.
#
#
# Using time series analysis for sales and demand forecasting is crucial for data analysis in business because it can enhance decision-making by providing reliable sales and demand forecasts. This helps organisations reduce costs, maximise profits, and optimise resource allocation.
#
#
# During this project, you will analyse the business scenario and explore the data set. You will then clean historical sales data, perform time series analysis using ARIMA, deep learning, or hybrid methods, and validate the models to ensure their accuracy in predicting future sales and demand patterns.
#
#
#
#
#
#
# Please set aside approximately **36 hours** to complete the topic project.
#
# <br>
#
# ## **Business context**
#
#
#
# The Nielsen BookScan service is the world’s largest continuous book sales tracking service in the world, operating in the UK, Ireland, Australia, New Zealand, India, South Africa, Italy, Spain, Mexico, Brazil, Poland, and Colombia. Nielsen BookScan collects transactional data at the point of sale, directly from tills and dispatch systems of all major book retailers. This ensures detailed and highly accurate sales information on which books are selling and at what price, giving clients the most up-to-date and relevant data. The Nielsen BookScan Total Consumer Market (TCM) data covers approximately 90% of all retail print book purchases in the UK. The remaining sites are specialised, such as gift shops, specialist booksellers, and tourist information centres.
#
#
# Nielsen BookScan can be used to:
# Monitor titles and authors against the competition and overall market.
# Analyse pricing and discounting by format or category.
# Gauge the success of marketing campaigns and promotions.
# See which categories are growing and declining.
# Learn what works in your market and how that might differ from other countries.
#
# Nielsen BookScan sales data can be analysed by various criteria, including category, publisher, and format,
# allowing users to see which genres are selling in which format. Users can track market trends to see which titles are driving the results, and patterns can easily be interpreted. In addition, the actual selling price is included. This inclusion makes it easier to identify trends for the level of discounting (e.g. by title, author, genre, format, region, and publisher) when analysing book sales.
#
# **Project context**
#
# Nielsen is seeking to invest in developing a new service aimed at small to medium-sized independent publishers. This service is aimed at supporting publishers in using historical sales data to make data-driven decisions about their future investment in new publications. Their publisher customers are interested in being able to make more accurate predictions of the overall sales profile post-publication for better stock control and initial investment, but they are also interested in understanding the useful economic life span that a title may have.
#
# Nielsen is targeting small to medium-sized independent publishers as their research has shown that there is a strong demand for this insight, but businesses cannot invest in this infrastructure and would pay a premium to have access to quality-assured data and analysis in this area. Producing a new publication requires a significant upfront investment, and they would like to be able to more accurately identify books with strong long-term potential. More specifically, they are looking for titles with sales patterns that exhibit well-established seasonal patterns and positive trends that show potential great returns and to learn more about these types of publications. Nielsen will then apply this understanding to their commission and print volume strategy to be more successful in acquiring titles that have longevity. Additionally, this will enable them to deliver better returns by ensuring the correct stock levels in relation to demand and avoiding over- or understocking, which can be costly.
#
# You will notice that some titles experience fluctuations in sales due to various factors, such as increased media attention or cultural relevance (e.g. the recent resurgence of interest in George Orwell’s 1984). However, certain books endure over time and are often studied in academic settings for their deeper significance.
#
# For this project, Nielsen has provided you with two data sets. The objective is to identify sales patterns that demonstrate seasonal trends or any other traits, providing insights to inform reordering, restocking, and reprinting decisions for various books (by their International Standard Book Number, or ISBN).
#
#
# <br>
#
# ## **Objective**
#
# By the end of this project, you will have conducted a comprehensive analysis on select books from Nielsen's data, identifying key sales patterns that exhibit clear seasonal trends or other distinctive characteristics. These insights will serve as a data-driven foundation for optimising procurement, re-ordering, and stocking decisions, ensuring efficient inventory management.
#
#
# In this Notebook, you will:
# - Import both datasets, resample weekly sales data to ensure missing weeks are filled with zeros, and convert ISBNs to strings and dates to datetime objects.
# - Filter out ISBNs with sales data beyond 2024-07-01, display these ISBNs, and plot their sales patterns for further analysis.
# - Investigate the general sales patterns across different time periods (1-12 years vs. 12-24 years) and analyse possible reasons for any noticeable changes.
# - Focus on two specific books, The Alchemist and The Very Hungry Caterpillar, for deeper analysis. Filter their data from 2012 onwards for further forecasting.
# - Perform time series decomposition, ACF/PACF analysis, and stationarity checks for both books. Use Auto ARIMA to identify the best model and forecast the final 32 weeks of data.
# - Prepare the data for machine learning models, create an XGBoost pipeline, tune parameters using grid search, and forecast the final 32 weeks for both books.
# - Build and tune an LSTM model using KerasTuner, forecast the final 32 weeks of data, and evaluate the performance using MAE and MAPE.
# - Apply both sequential and parallel hybrid models combining SARIMA and LSTM, tune the models, and evaluate their performance using various metrics.
# - Aggregate weekly data to monthly data, train XGBoost and SARIMA models to forecast eight months, and compare results with weekly predictions.
#
#
#
#
# You will also write a report summarising the results of your findings and recommendations.
#
#
# <br></br>
#
# ## **Assessment criteria**
# By completing this project, you will be able to provide evidence that you can:
#
# - Pre-process a real industry data set to make it suitable for time series analysis.
# - Apply various statistical tests to understand underlying characteristics of the data such as stationarity, seasonality and autocorrelation patterns.
# - Perform time series decomposition to separate the data into trend, seasonal and residual components.
# - Implement time series forecasting models.
# - Fine-tune the model to improve model performance.
#
#
#
#
# <br></br>
#
# ## **Project guidance**
#
# **Import packages and data:**
# 1. Load the appropriate libraries and models.
# 2. Import the data set with the provided URL:
#   - Data set's Drive link: https://drive.google.com/drive/folders/1o8fZaaECKUnLYJAK4pqR4e3WyOFYhc_o
#   - Each file has four tabs, so ensure that you read the data from all four tabs.
#
# **Conducting initial data investigation:**
#
# 1. Note that the data provided is weekly data. If no sales happened in a particular week, there will be no data representation for that week. This means that the data is not at fixed intervals.
# As a result, resample the data and fill in missing values with 0, such that even weeks with 0 sales is represented.
# 2. Convert the ISBNs to a string value.
# 3. Convert date to datetime object. (Recall that setting the date as the index has several advantages for time series handling.)
# 4. Filter out the ISBNs (from all four tabs) wherein sales data exists beyond 2024-07-01. Show all the ISBNs that satisfy this criterion. Capture this in your report.
# 5. Plot the data of all the ISBNs from the previous step by placing them in a loop.
# 6. Investigate these plots to understand the general sales patterns, and comment on the general patterns visible in the data. Do the patterns drastically change for the period 1–12 years vs the period 12–24 years? Explain why or why not with possible reasons.
# 7. Select two books from the list (*The Alchemist* and *The Very Hungry Caterpillar*) for further analysis. Focus on the period >2012-01-01. Filter the sales data for both these books to retain the date range >2012-01-01, until the final datapoint.
#
# **Classical techniques:**
# 1. Perform decomposition on the data for both books. Determine what type of decomposition is suitable for each book, and comment on the components' characteristics.
# 2. Perform ACF and PACF on both books. Comment on the results and what they indicate.
# 3. Check for stationarity of the data for both books. Comment on the results and what they indicate.
# 4. Perform Auto ARIMA on both books. **The forecast horizon is the final 32 weeks of data.** All prior data (from 2012-01-01 onwards) can be used as the training data. Set reasonable bounds for Auto ARIMA's various parameters so that Auto ARIMA can identify the most suitable model.
# 5. Comment on the best model provided by Auto ARIMA for both books.
# 6. Find the residuals of the 'best' model for both books. Comment on the residuals.
# 7. Use the best model to predict the final 32 weeks of data. Plot the prediction along with the confidence intervals for both books.
# 8. Comment on how the prediction compares with the actual values.
#
# **Machine learning and deep learning techniques**
# 1. Prepare the data to feed into the machine learning models. The forecast horizon is **32 weeks**. The training data consists of all prior data, up to 2012-01-01.
# 2. Create the required pipeline for the XGBoost model.
# 3. Perform cross-validation.
# 4. Perform parameter tuning (including window_length) using grid search.
# 5. Identify the best models.
# 6. Use the best models to forecast the **final 32 weeks** of sales data for both books.
# 7. Plot the original data along with the predictions.
# 8. Display the MAE and MAPE.
# 9. Create an LSTM model for both books.
# 10. Apply KerasTuner, and perform hyperparameter tuning using the training data, for both books.
# 11. Use the best model to predict the **final 32 weeks** of data for both books.
# 12. Plot the original data along with the predictions.
# 13. Display the MAE and MAPE.
#
# **Hybrid model**
# 1. Apply a hybrid model of SARIMA and LSTM in sequential combination wherein the residuals from SARIMA will be forecasted using LSTM. The final prediction will be the sum of the predictions from SARIMA and LSTM. The LSTM will be trained on the residuals obtained during the training of the SARIMA model. **The forecast horizon will be the final 32 weeks**. Use KerasTuner to get the best model. Plot the results. Display the MAE and MAPE, and comment on the results.
# 2. Apply a hybrid model of SARIMA and LSTM in parallel combination wherein the predictions from SARIMA and the predictions from LSTM will be combined in the form of a weighted average. The final prediction will be the weighted sum of the predictions from SARIMA and LSTM. Both the SARIMA and the LSTM will be trained separately on the complete training set. **The forecast horizon will be the final 32 weeks**. Use KerasTuner to get the best model. Plot the results. Display the MAE and MAPE, and comment on the results.
# 3. Modify the weightage in the parallel combination model to get different results. Find the weightage giving the best results, and comment on those results.
#
# **Monthly prediction**
# 1. Instead of a weekly prediction, perform a monthly prediction. Aggregate the weekly sales data to monthly sales data for both books.
# 2. Train the XGBoost model on this data. Forecast using the trained model. The forecast horizon is 8 months. Plot the results, and calculate the MAE and MAPE.
# 3. Train the SARIMA model (using Auto ARIMA) on this data. Forecast using the trained model. The forecast horizon is 8 months. Plot the results, and calculate the MAE and MAPE.
# 4. Compare and contrast the monthly predictions of both books against the weekly predictions. Comment on which one is more accurate or if they are the same.
#
# **Report:**
# 1. Document your approach and major inferences from the data analysis.
# 2. When you have completed the project:
#   - Download your completed Notebook as an IPYNB (Jupyter Notebook) or PY (Python) file. Save the file as follows: **LastName_FirstName_CAM_C301_Week_9and10_Topic_project.ipynb**.
#   - Prepare a detailed report (between 800–1,000 words) that includes:
#     - an overview of your approach
#     - a description of your analysis
#     - an explanation of the insights you identified
#     - any final insights, based on the output obtained from the various models employed.
#   - Save the document as a PDF named according to the following convention: **LastName_FirstName_CAM_C301_Week_9and10_Topic_project.pdf**.
#   - Submit your Notebook and PDF document.
#
#
# <br></br>
# > **Declaration**
# >
# > By submitting your project, you indicate that the work is your own and has been created with academic integrity. Refer to the Cambridge plagiarism regulations.

# %% [markdown]
# # Continuation of the Analysis from notebook3

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.seasonal import STL
import statsmodels.api as sm
import lightgbm as lgb
from sktime.forecasting.compose import (TransformedTargetForecaster, make_reduction)
from sktime.forecasting.model_selection import (ExpandingWindowSplitter, ForecastingGridSearchCV)
from sklearn.model_selection import GridSearchCV
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sktime.forecasting.trend import PolynomialTrendForecaster
from sktime.transformations.series.detrend import Deseasonalizer, Detrender
import calendar
from sktime.transformations.series.difference import Differencer
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow.keras.layers import Input
from sklearn.model_selection import TimeSeriesSplit
from keras_tuner import RandomSearch
import keras_tuner as kt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
from datetime import datetime, timedelta
from keras_tuner import BayesianOptimization
from tensorflow.keras.layers import LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from sklearn.base import BaseEstimator, TransformerMixin
tf.random.set_seed(0)

from scipy.stats import jarque_bera
from statsmodels.stats.diagnostic import het_arch
import warnings
# Suppress specific warnings.
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /var/folders/fw/y66wb9yj5c72qt_vyyz__c2r0000gn/T/ipykernel_39985/984125539.py:25: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
# Load parquet format. This is better than csv format, because it conserves all the original metadata, including frequency, contained in the original dataframe saved from notebook1 (everything comes back exactly as saved)
df_uk_weekly_post2012 = pd.read_parquet('df_uk_weekly_post2012.parquet')

# Display the first few rows of the dataset
display(df_uk_weekly_post2012.head(2))
# Out:
#                      ISBN                        Title         Author  \
# End_Date
# 2012-01-07  9780241003008  The Very Hungry Caterpillar    Carle, Eric
# 2012-01-07  9780722532935                The Alchemist  Coelho, Paulo
#
#             Interval  Volume    Value     ASP   RRP    Binding       Imprint  \
# End_Date
# 2012-01-07    201201     512  2522.13  4.9260  7.99   Hardback  Puffin Books
# 2012-01-07    201201     518  3601.76  6.9532  9.99  Paperback      Thorsons
#
#               Publisher_Group                    Product_Class  \
# End_Date
# 2012-01-07        Penguin Grp               Y1.3 Picture Books
# 2012-01-07  HarperCollins Grp  F1.1 General & Literary Fiction
#
#                                   Category
# End_Date
# 2012-01-07  Y Children's, YA & Educational
# 2012-01-07                 F Adult Fiction

# %% [markdown]
# ### Fix the Misaligned Frequency

# %%
# Repeat for the "The Very Hungry Caterpillar" data
hung_caterp = df_uk_weekly_post2012[df_uk_weekly_post2012['ISBN'] == '9780241003008']['Volume']
# Ensure the Hungry Caterpillar data has the same frequency as the original dataset
hung_caterp = hung_caterp.asfreq('W-SAT')
# Fill NAs with 0
hung_caterp = hung_caterp.fillna(0)
print(hung_caterp.isna().sum())
print(hung_caterp.index.inferred_freq)
# Out:
# 0
# W-SAT

# %%
# Repeat for the "The Alchemist" data
alchemist = df_uk_weekly_post2012[df_uk_weekly_post2012['ISBN'] == '9780722532935']['Volume']
# Ensure the Alchemist data has the same frequency as the original dataset
alchemist = alchemist.asfreq('W-SAT')
# Fill NAs with 0
alchemist = alchemist.fillna(0)
print(alchemist.isna().sum())
print(alchemist.index.inferred_freq)
# Out:
# 0
# W-SAT

# %% [markdown]
# ### Split the data into training and test sets

# %%
# Split the data for both books into train and test sets.
# Split the data for the Hungry Caterpillar
ts_train_hung_caterp = hung_caterp[:-32]
ts_test_hung_caterp = hung_caterp[-32:]

# Split the data for the Alchemist
ts_train_alchemist = alchemist[:-32]
ts_test_alchemist = alchemist[-32:]

# %% [markdown]
# # Sequential Hybrid Models

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
import calendar
from datetime import datetime, timedelta
import warnings

# Statistical analysis and time series
import statsmodels.api as sm
import statsmodels.graphics.api as smgraphics
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller, kpss, acf, pacf
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch
from pmdarima.arima import auto_arima
from scipy.stats import jarque_bera

# Machine Learning
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# Time series forecasting (sktime)
from sktime.forecasting.compose import TransformedTargetForecaster, make_reduction
from sktime.forecasting.model_selection import ExpandingWindowSplitter, ForecastingGridSearchCV
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sktime.forecasting.trend import PolynomialTrendForecaster
from sktime.transformations.series.detrend import Deseasonalizer, Detrender
from sktime.transformations.series.difference import Differencer

# Deep Learning (TensorFlow/Keras)
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input, LayerNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras_tuner as kt
from keras_tuner import RandomSearch, BayesianOptimization

# Visualization
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# Holidays
from pandas.tseries.holiday import USFederalHolidayCalendar

# Set random seeds for reproducibility
tf.random.set_seed(0)
np.random.seed(0)

# Suppress warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /opt/miniconda3/envs/ts/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ### Modeling the Very Hungry Caterpillar: Sequential Combination of SARIMA and LSTM

# %%
# Using same data used for the LSTM models
# The hungry caterpillar set
hung_caterp # This variable was generated at the beginning of the notebook
detrender = Detrender()
hung_caterp_detrended = detrender.fit_transform(hung_caterp) 
hung_caterp_detrended = hung_caterp_detrended.asfreq('W-SAT')
# Fill NAs with 0
hung_caterp_detrended = hung_caterp_detrended.fillna(0)

print(f"The Hungry Caterpillar data set info:")
print(hung_caterp_detrended.info())

# The alchemist set
print(f"\nThe Alchemist data set info:")
print(alchemist.info())
# Out:
# The Hungry Caterpillar data set info:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 655 entries, 2012-01-07 to 2024-07-20
# Freq: W-SAT
# Series name: Volume
# Non-Null Count  Dtype
# --------------  -----
# 655 non-null    float64
# dtypes: float64(1)
# memory usage: 10.2 KB
# None
#
# The Alchemist data set info:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 655 entries, 2012-01-07 to 2024-07-20
# Freq: W-SAT
# Series name: Volume
# Non-Null Count  Dtype
# --------------  -----
# 655 non-null    float64
# dtypes: float64(1)
# memory usage: 10.2 KB
# None

# %%
# Split the data for both books into train and test sets.
# Split data for the Hungry Caterpillar
ts_train_hung_caterp = hung_caterp[:-32]
ts_test_hung_caterp = hung_caterp[-32:]

# Split the data for the Hungry Caterpillar Detrended
ts_train_hung_caterp_detrended = hung_caterp_detrended[:-32]
ts_test_hung_caterp_detrended = hung_caterp_detrended[-32:]

# Split the data for the Alchemist
alchemist = df_uk_weekly_post2012[df_uk_weekly_post2012['ISBN'] == '9780722532935']['Volume']
# Ensure the Alchemist data has the same frequency as the original dataset
alchemist = alchemist.asfreq('W-SAT')
# Fill NAs with 0
alchemist = alchemist.fillna(0)
print(alchemist.index.inferred_freq)
print(alchemist.isna().sum()) 
# Split the Alchemist data into train and test sets
ts_train_alchemist = alchemist[:-32]
ts_test_alchemist = alchemist[-32:]
# Out:
# W-SAT
# 0

# %% [markdown]
# ### Run the SARIMA model on the detrended hungry caterpillar data for better performance

# %%
# Use Best Sarima model for hungry caterpillar: Based on previous analysis, Model 5 had the same performance than best autoarima model: ARIMA(1,0,0)(1,0,1)[52]

# Fit SARIMA model with optimized parameters (correct)
sarima_model_hc_detrended = SARIMAX(ts_train_hung_caterp_detrended, 
                                  order=(1,0,1), 
                                  seasonal_order=(1,0,1,52))
sarima_fit_hc_detrended = sarima_model_hc_detrended.fit(disp=False)

# Get predictions for TRAIN SET only (corrected)
sarima_pred_hc_detrended_train = sarima_fit_hc_detrended.get_prediction(
    start=ts_train_hung_caterp_detrended.index[0], 
    end=ts_train_hung_caterp_detrended.index[-1]
)
sarima_pred_mean_hc_detrended_train = sarima_pred_hc_detrended_train.predicted_mean
sarima_pred_conf_int_hc_detrended_train = sarima_pred_hc_detrended_train.conf_int()

# Get predictions for TEST SET only (corrected)
sarima_pred_hc_detrended_test = sarima_fit_hc_detrended.get_prediction(
    start=ts_test_hung_caterp_detrended.index[0],
    end=ts_test_hung_caterp_detrended.index[-1]
)
sarima_pred_mean_hc_detrended_test = sarima_pred_hc_detrended_test.predicted_mean
sarima_pred_conf_int_hc_detrended_test = sarima_pred_hc_detrended_test.conf_int()

# Get predictions for FULL DATASET (corrected)
sarima_pred_full_detrended = sarima_fit_hc_detrended.get_prediction(
    start=hung_caterp_detrended.index[0],
    end=hung_caterp_detrended.index[-1]
)
sarima_pred_mean_full_detrended = sarima_pred_full_detrended.predicted_mean
sarima_pred_conf_int_full_detrended = sarima_pred_full_detrended.conf_int()
    
# Calculate residuals for Full SET
sarima_full_residuals_hc_detrended = hung_caterp_detrended - sarima_pred_mean_full_detrended

# %%
# Use ADF test to make sure residuals from full set have no remaining seasonality/trend
adf_result_hc_detrended_sarima = adfuller(sarima_full_residuals_hc_detrended.dropna())
print(f"ADF p-value: {adf_result_hc_detrended_sarima[1]:.4f}")  # Should be < 0.05. If p > 0.05, consider refining SARIMA further (e.g., adding differencing or seasonal terms).
# Out:
# ADF p-value: 0.0000

# %% [markdown]
# ### Modeling the Very Hungry Caterpillar with unprocessed data

# %%
# Use Best Sarima model for hungry caterpillar: Based on previous analysis, Model 5 had the same performance than best autoarima model: ARIMA(1,0,0)(1,0,1)[52]
# Fit SARIMA model with optimized parameters (correct)
sarima_model_hc = SARIMAX(ts_train_hung_caterp, 
                                  order=(1,0,1), 
                                  seasonal_order=(1,0,1,52))
sarima_fit_hc = sarima_model_hc.fit(disp=False)

# Get predictions for TRAIN SET only (corrected)
sarima_pred_hc_train = sarima_fit_hc.get_prediction(
    start=ts_train_hung_caterp.index[0], 
    end=ts_train_hung_caterp.index[-1]
)
sarima_pred_mean_hc_train = sarima_pred_hc_train.predicted_mean
sarima_pred_conf_int_hc_train = sarima_pred_hc_train.conf_int()

# Get predictions for TEST SET only (corrected)
sarima_pred_hc_test = sarima_fit_hc.get_prediction(
    start=ts_test_hung_caterp.index[0], 
    end=ts_test_hung_caterp.index[-1]
)
sarima_pred_mean_hc_test = sarima_pred_hc_test.predicted_mean
sarima_pred_conf_int_hc_test = sarima_pred_hc_test.conf_int()

# Get predictions for FULL DATASET (corrected)
sarima_pred_full_hc = sarima_fit_hc.get_prediction(
    start=hung_caterp.index[0],
    end=hung_caterp.index[-1]
)
sarima_pred_mean_full_hc = sarima_pred_full_hc.predicted_mean
sarima_pred_conf_int_full_hc = sarima_pred_full_hc.conf_int()

# Calculate residuals for Full SET
sarima_full_residuals_hc = hung_caterp - sarima_pred_mean_full_hc

# %%
# Use ADF test to make sure residuals from full set have no remaining seasonality/trend
adf_result_hc_sarima = adfuller(sarima_full_residuals_hc.dropna())
print(f"ADF p-value: {adf_result_hc_sarima[1]:.4f}")  # Should be < 0.05. If p > 0.05, consider refining SARIMA further (e.g., adding differencing or seasonal terms).
# Out:
# ADF p-value: 0.7140

# %%
# Plotting
plt.figure(figsize=(18, 8))  # Slightly taller for better spacing
training_start_date = '2020-01-01'

# 1. Main plot with data and forecast
plt.subplot(2, 1, 1)
# Fixed the incorrect comparison in this line:
plt.plot(ts_train_hung_caterp[ts_train_hung_caterp.index >= training_start_date],
         label='Training Raw Data', color='black', linewidth=2)
plt.plot(ts_test_hung_caterp[ts_test_hung_caterp.index >= training_start_date],
         label='Test Raw Data', color='black', linewidth=2, linestyle=':')
plt.plot(ts_train_hung_caterp_detrended[ts_train_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Training Data', color='gray', linewidth=2)
plt.plot(ts_test_hung_caterp_detrended[ts_test_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Test Data', color='gray', linewidth=2, linestyle=':')

# Plot processed SARIMA for detrended data
plt.plot(sarima_pred_mean_hc_detrended_train[sarima_pred_mean_hc_detrended_train.index >= training_start_date],
         label='SARIMA Model Fit (Detrended)', color="#267509", linewidth=2, linestyle='--')
plt.plot(sarima_pred_mean_hc_detrended_test,
         label='Forecast (Detrended)',
         linestyle='-',
         linewidth=2,
         color="#0e7aff")
plt.fill_between(sarima_pred_conf_int_hc_detrended_test.index,
                sarima_pred_conf_int_hc_detrended_test.iloc[:, 0],
                sarima_pred_conf_int_hc_detrended_test.iloc[:, 1],
                color='#0e7aff', alpha=0.1)

# Plot RAW SARIMA results
plt.plot(sarima_pred_mean_hc_train[sarima_pred_mean_hc_train.index >= training_start_date],
         label='SARIMA Model Fit (Raw)', color="#d30eff", linewidth=2, linestyle=':')
plt.plot(sarima_pred_mean_hc_test,
         label='Forecast (Raw)',
         linestyle='-',
         linewidth=2,
         color="#ff7f0e")
plt.fill_between(sarima_pred_conf_int_hc_test.index,
                sarima_pred_conf_int_hc_test.iloc[:, 0],
                sarima_pred_conf_int_hc_test.iloc[:, 1],
                color='#ff7f0e', alpha=0.1)

plt.title('Very Hungry Caterpillar: SARIMA Model Comparison', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))  # Moved legend outside
plt.grid(False)

# 2. Residuals plot
plt.subplot(2, 1, 2)
plt.plot(sarima_full_residuals_hc_detrended[sarima_full_residuals_hc_detrended.index >= training_start_date],
         label='Residuals (Detrended)', color="#0e7aff", linewidth=2)
plt.plot(sarima_full_residuals_hc[sarima_full_residuals_hc.index >= training_start_date],
         label='Residuals (Raw)', color="#ff7f0e", linewidth=2, alpha=1, linestyle='--')
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.title('Model Residuals Comparison', fontsize=14)
plt.ylabel('Residual Value', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
plt.grid(False)

# Residual metrics annotations
residual_metrics_detrended = (f"Residuals Detrended:\n"
                             f"Mean: {sarima_full_residuals_hc_detrended.mean():.2f}\n"
                             f"Std Dev: {sarima_full_residuals_hc_detrended.std():.2f}\n"
                             f"ADF p-value: {adf_result_hc_detrended_sarima[1]:.4f}")

residual_metrics_raw = (f"Residuals RAW :\n"
                       f"Mean: {sarima_full_residuals_hc.mean():.2f}\n"
                       f"Std Dev: {sarima_full_residuals_hc.std():.2f}\n"
                       f"ADF p-value: {adf_result_hc_sarima[1]:.4f}")

plt.annotate(residual_metrics_detrended, xy=(0.01, 0.8), xycoords='axes fraction',
             bbox=dict(boxstyle="round", fc="white", ec="#2ca02c", alpha=0.8),
             fontsize=9)

plt.annotate(residual_metrics_raw, xy=(0.01, 0.55), xycoords='axes fraction',
             bbox=dict(boxstyle="round", fc="white", ec="#ff7f0e", alpha=0.8),
             fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Run the LSTM model on the residuals of the SARIMA model

# %%
# Define train and test sets for the residuals from detrended SARIMA model
ts_train_hc_detrended_residuals_sarima = sarima_full_residuals_hc_detrended[:-32]
ts_test_hc_detrended_residuals_sarima = sarima_full_residuals_hc_detrended[-32:]

# Define train and test sets for the residuals from raw SARIMA model
ts_train_hc_raw_residuals_sarima = sarima_full_residuals_hc[:-32]
ts_test_hc_raw_residuals_sarima = sarima_full_residuals_hc[-32:]

# %%
# This class is designed to handle multi-step LSTM forecasting with a focus on simplicity and efficiency.
class MultiStepLSTMForecaster:
    """
    A streamlined class for multi-step LSTM time series forecasting
    """
    def __init__(self, lookback=52, forecast=32, lstm_units=[128, 64], dropout_rate=0.2):
        self.lookback = lookback
        self.forecast = forecast
        self.lstm_units = lstm_units
        self.dropout_rate = dropout_rate
        self.scaler = None
        self.model = None
        self.history = None
        
    def prepare_data(self, ts_train, ts_test=None):
        """
        Prepare and normalize time series data
        
        Args:
            ts_train: Training time series data (pandas Series)
            ts_test: Test time series data (pandas Series, optional)
        
        Returns:
            Tuple of processed data
        """
        # Reshape data
        train_reshaped = ts_train.values.reshape(-1, 1)
        
        # Initialize and fit scaler on training data
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        train_scaled = self.scaler.fit_transform(train_reshaped)
        
        # Process test data if provided
        test_scaled = None
        if ts_test is not None:
            test_reshaped = ts_test.values.reshape(-1, 1)
            test_scaled = self.scaler.transform(test_reshaped)
        
        return train_scaled, test_scaled
    
    def create_sequences(self, data, mode='train'):
        """
        Create sequences for multi-step forecasting
        
        Args:
            data: Scaled time series data
            mode: 'train' or 'test'
        
        Returns:
            input_sequences, output_sequences
        """
        input_sequences = []
        output_sequences = []
        
        if mode == 'train':
            # Validate data length
            if len(data) < self.lookback + self.forecast:
                raise ValueError(f"Training needs {self.lookback + self.forecast} points, got {len(data)}")
            
            # Create overlapping sequences for training
            for i in range(len(data) - self.lookback - self.forecast + 1):
                input_sequences.append(data[i:i+self.lookback])
                output_sequences.append(data[i+self.lookback:i+self.lookback+self.forecast].flatten())
                
        else:  # test mode
            # Pad with zeros if needed
            if len(data) < self.lookback:
                padded_data = np.zeros((self.lookback, 1))
                padded_data[-len(data):] = data
                data = padded_data
            
            # Create one sequence from the end of the data
            input_sequences.append(data[-self.lookback:])
            output_sequences.append(np.array([]))  # Empty for test
        
        return np.array(input_sequences), np.array(output_sequences)
    
    def build_model(self, architecture='simple'):
        """
        Build the multi-step LSTM model
        
        Args:
            architecture: 'simple' (original working) or 'complex' (enhanced)
        """
        model = Sequential()
        if architecture == 'simple':
            # Original working architecture - simpler and often better for time series
            model.add(LSTM(self.lstm_units[0], 
                          return_sequences=len(self.lstm_units) > 1,
                          input_shape=(self.lookback, 1)))
            model.add(Dropout(self.dropout_rate))
            
            # Additional LSTM layers
            for i, units in enumerate(self.lstm_units[1:], 1):
                return_seq = i < len(self.lstm_units) - 1
                model.add(LSTM(units, return_sequences=return_seq))
                model.add(Dropout(self.dropout_rate))
            
            # Direct output layer
            model.add(Dense(self.forecast))
            
            # Simple optimizer
            model.compile(optimizer=Adam(learning_rate=0.001),
                         loss='mse',
                         metrics=['mae'])
        
        else:  # complex architecture
            # Enhanced architecture with more regularization
            model.add(LSTM(self.lstm_units[0], 
                          return_sequences=True,
                          input_shape=(self.lookback, 1),
                          recurrent_dropout=0.1))
            model.add(Dropout(self.dropout_rate))
            
            for i, units in enumerate(self.lstm_units[1:], 1):
                return_seq = i < len(self.lstm_units) - 1
                model.add(LSTM(units, return_sequences=return_seq, recurrent_dropout=0.1))
                model.add(Dropout(self.dropout_rate))
            
            # Additional dense layer
            model.add(Dense(64, activation='relu'))
            model.add(Dropout(self.dropout_rate))
            model.add(Dense(self.forecast, activation='linear'))
            
            # Enhanced optimizer
            model.compile(optimizer=Adam(learning_rate=0.001, clipnorm=1.0),
                         loss='mse',
                         metrics=['mae'])
        
        self.model = model
        return model
    
    def train(self, X_train, y_train, batch_size=16, epochs=100, validation_split=0.2, 
              early_stopping=True, patience=25, verbose=1):
        """
        Train the LSTM model with optimal settings
        """
        if self.model is None:
            self.build_model()
        
        callbacks = []
        
        if early_stopping:
            callbacks.extend([
                EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True, min_delta=1e-6),
                ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=15, min_lr=1e-8, verbose=1)
            ])
        
        self.history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_split=validation_split,
            callbacks=callbacks,
            verbose=verbose
        )
        
        return self.history
    
    def predict(self, X_test):
        """
        Make predictions and inverse transform to original scale
        """
        if self.model is None:
            raise ValueError("Model must be trained before making predictions")
        
        # Ensure tensor consistency to avoid retracing warnings
        X_test_tensor = tf.convert_to_tensor(X_test, dtype=tf.float32)
        
        # Make predictions
        predictions_scaled = self.model.predict(X_test_tensor, verbose=0)
        
        # Inverse transform to original scale
        predictions_reshaped = predictions_scaled.reshape(-1, 1)
        predictions_original = self.scaler.inverse_transform(predictions_reshaped).flatten()
        
        return predictions_original
    
    def create_forecast_dataframe(self, predictions, last_date, freq='W-SAT'):
        """
        Create a formatted DataFrame with forecast dates and predictions
        """
        forecast_dates = pd.date_range(
            start=last_date + pd.Timedelta(weeks=1),
            periods=len(predictions),
            freq=freq
        )
        
        forecast_df = pd.DataFrame({
            'Date': forecast_dates,
            'Predictions': predictions
        }).set_index('Date')
        
        return forecast_df

# %%
def run_lstm_forecast(ts_train, ts_test=None, lookback=52, forecast=32, 
                     lstm_units=[128, 64], dropout_rate=0.2, epochs=100, 
                     early_stopping=False, architecture='simple'):
    """
    Complete streamlined LSTM forecasting workflow
    
    Args:
        ts_train: Training time series (pandas Series)
        ts_test: Test time series (pandas Series, optional)
        lookback: Number of input timesteps
        forecast: Number of output timesteps
        lstm_units: List of LSTM layer sizes
        dropout_rate: Dropout rate
        epochs: Training epochs
        early_stopping: Whether to use early stopping
        architecture: 'simple' or 'complex' model architecture
    
    Returns:
        forecaster, predictions_df, history
    """
    
    # Initialize forecaster
    forecaster = MultiStepLSTMForecaster(
        lookback=lookback,
        forecast=forecast,
        lstm_units=lstm_units,
        dropout_rate=dropout_rate
    )
    
    # Prepare data
    train_scaled, test_scaled = forecaster.prepare_data(ts_train, ts_test)
    
    # Create sequences
    X_train, y_train = forecaster.create_sequences(train_scaled, mode='train')
    X_test, _ = forecaster.create_sequences(train_scaled, mode='test')
    
    print(f"Training sequences: X_train {X_train.shape}, y_train {y_train.shape}")
    print(f"Test sequences: X_test {X_test.shape}")
    print(f"Using {architecture} architecture")
    
    # Build and train model with specified architecture
    forecaster.build_model(architecture=architecture)
    history = forecaster.train(X_train, y_train, epochs=epochs, early_stopping=early_stopping)
    
    # Make predictions
    predictions = forecaster.predict(X_test)
    
    # Create forecast DataFrame
    predictions_df = forecaster.create_forecast_dataframe(
        predictions, ts_train.index[-1]
    )
    
    print(f"\n{forecast}-week forecast:")
    print(predictions_df.head())
    print(f"Prediction range: {predictions.min():.2f} to {predictions.max():.2f}")
    
    return forecaster, predictions_df, history

# %%
# Run LSTM forecaster on the residuals of the Sarima model without any additional preprocessing
forecaster_hc_detrended_residuals_sarima_lstm_model, predictions_df_hc_detrended_residuals_sarima_lstm, history_hc_detrended_residuals_sarima_lstm = run_lstm_forecast(
    ts_train=ts_train_hc_detrended_residuals_sarima,
    ts_test=ts_test_hc_detrended_residuals_sarima,
    lookback=52,
    forecast=32,
    epochs=100,
    architecture='simple'  # Use the working architecture
)
# Out:
# Training sequences: X_train (540, 52, 1), y_train (540, 32)
# Test sequences: X_test (1, 52, 1)
# Using simple architecture
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 27/27 [==============================] - 3s 45ms/step - loss: 0.0535 - mae: 0.1830 - val_loss: 0.0082 - val_mae: 0.0670
# Epoch 2/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0146 - mae: 0.0907 - val_loss: 0.0071 - val_mae: 0.0589
# Epoch 3/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0124 - mae: 0.0825 - val_loss: 0.0075 - val_mae: 0.0623
# Epoch 4/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0116 - mae: 0.0792 - val_loss: 0.0070 - val_mae: 0.0588
# Epoch 5/100
# ...

# %%
# Run LSTM forecaster on the residuals of the Sarima model for raw data without any additional preprocessing
forecaster_hc_raw_residuals_sarima_lstm_model, predictions_df_hc_raw_residuals_sarima_lstm, history_hc_raw_residuals_sarima_lstm = run_lstm_forecast(
    ts_train=ts_train_hc_raw_residuals_sarima,
    ts_test=ts_test_hc_raw_residuals_sarima,
    lookback=52,
    forecast=32,
    epochs=100,
    architecture='simple')  # Use the working architecture
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Training sequences: X_train (540, 52, 1), y_train (540, 32)
# Test sequences: X_test (1, 52, 1)
# Using simple architecture
# Epoch 1/100
# 27/27 [==============================] - 2s 44ms/step - loss: 0.0639 - mae: 0.2023 - val_loss: 0.0077 - val_mae: 0.0623
# Epoch 2/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0151 - mae: 0.0935 - val_loss: 0.0064 - val_mae: 0.0540
# Epoch 3/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0118 - mae: 0.0814 - val_loss: 0.0060 - val_mae: 0.0507
# Epoch 4/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0105 - mae: 0.0753 - val_loss: 0.0057 - val_mae: 0.0471
# Epoch 5/100
# ...

# %%
# Ensure predictions are aligned with test data timestamps
def align_predictions_with_test(predictions_df, test_series):
    """Align predictions DataFrame index with test series index"""
    # Convert predictions to Series if needed
    if isinstance(predictions_df, pd.DataFrame):
        predictions_series = predictions_df['Predictions']
    else:
        predictions_series = predictions_df
        
    # Find overlapping period
    common_index = test_series.index.intersection(predictions_series.index)
    
    if len(common_index) == 0:
        raise ValueError("No overlapping dates between predictions and test data")
        
    return test_series.loc[common_index], predictions_series.loc[common_index]

# Calculate metrics for each model
def calculate_model_metrics(test_data, predictions, model_name):
    """Calculate and format metrics for a single model"""
    try:
        # Align predictions with test data
        y_true, y_pred = align_predictions_with_test(predictions, test_data)
        
        mae = mean_absolute_error(y_true, y_pred)
        mape = mean_absolute_percentage_error(y_true, y_pred)
        
        return f"{model_name}: MAE={mae:.2f}, MAPE={mape:.2%}"
    except Exception as e:
        return f"{model_name}: Error calculating metrics - {str(e)}"


# Calculate metric for Hybrid Model
hybrid_forecast_test_hc_raw = (sarima_pred_mean_hc_test + predictions_df_hc_raw_residuals_sarima_lstm['Predictions'])
hybrid_forecast_test_hc_detrended = (sarima_pred_mean_hc_detrended_test + predictions_df_hc_detrended_residuals_sarima_lstm['Predictions'])

# Calculate metrics for all models
metrics_lstm_residuals_hc = "\n".join([
    calculate_model_metrics(ts_test_hc_detrended_residuals_sarima, predictions_df_hc_detrended_residuals_sarima_lstm, "LSTM Residuals Model The Hung Caterpillar (Detrended)"),
    calculate_model_metrics(ts_test_hc_raw_residuals_sarima, predictions_df_hc_raw_residuals_sarima_lstm, "LSTM Residuals Model The Hung Caterpillar (Raw)"),
    calculate_model_metrics(ts_test_hung_caterp, sarima_pred_mean_hc_test, "Sarima Model The Hung Caterpillar (RAW)"),
    calculate_model_metrics(ts_test_hung_caterp_detrended, sarima_pred_mean_hc_detrended_test, "Sarima Model The Hung Caterpillar (Detrended)"),
    calculate_model_metrics(ts_test_hung_caterp, hybrid_forecast_test_hc_raw, "Hybrid Model The Hung Caterpillar (RAW)"),
    calculate_model_metrics(ts_test_hung_caterp_detrended, hybrid_forecast_test_hc_detrended, "Hybrid Model The Hung Caterpillar (Detrended)")
])
print("Metrics for LSTM Residuals Models The Hung Caterpillar:")
print(metrics_lstm_residuals_hc)
# Out:
# Metrics for LSTM Residuals Models The Hung Caterpillar:
# LSTM Residuals Model The Hung Caterpillar (Detrended): MAE=366.75, MAPE=101.67%
# LSTM Residuals Model The Hung Caterpillar (Raw): MAE=849.31, MAPE=103.01%
# Sarima Model The Hung Caterpillar (RAW): MAE=917.69, MAPE=38.92%
# Sarima Model The Hung Caterpillar (Detrended): MAE=374.88, MAPE=102.85%
# Hybrid Model The Hung Caterpillar (RAW): MAE=849.31, MAPE=36.12%
# Hybrid Model The Hung Caterpillar (Detrended): MAE=366.75, MAPE=94.12%

# %% [markdown]
# #### Calculate mean and standard deviation of the residuals for residual model

# %%
# Calculate Mean and STD of residuals for LSTM model detrended
lstm_validation_residuals = predictions_df_hc_detrended_residuals_sarima_lstm['Predictions'] - ts_test_hc_detrended_residuals_sarima
lstm_mean = np.mean(lstm_validation_residuals)
lstm_std = np.std(lstm_validation_residuals)
print(f"LSTM Residuals Model The Hung Caterpillar (Detrended) - Mean: {lstm_mean:.2f}, STD: {lstm_std:.2f}")

# Calculate Mean and STD of residuals for SARIMA model detrended
sarima_validation_residuals_detrended = sarima_pred_mean_hc_detrended_test - ts_test_hung_caterp_detrended
sarima_mean_detrended = np.mean(sarima_validation_residuals_detrended)
sarima_std_detrended = np.std(sarima_validation_residuals_detrended)
print(f"SARIMA Model The Hung Caterpillar (Detrended) - Mean: {sarima_mean_detrended:.2f}, STD: {sarima_std_detrended:.2f}")
# Out:
# LSTM Residuals Model The Hung Caterpillar (Detrended) - Mean: -133.18, STD: 449.86
# SARIMA Model The Hung Caterpillar (Detrended) - Mean: -158.18, STD: 448.66

# %%
plt.figure(figsize=(18, 8))
training_start_date = '2020-01-01'

# 1. Main plot with data and forecast
plt.subplot(2, 1, 1)

# Plot actual data
plt.plot(ts_train_hung_caterp_detrended[ts_train_hung_caterp_detrended.index >= training_start_date],
         label='Training Data (Detrended)', color="#000000", linewidth=2)
plt.plot(ts_test_hung_caterp_detrended[ts_test_hung_caterp_detrended.index >= training_start_date],
         label='Test Data (Detrended)', color="#989898", linewidth=2)

# Plot SARIMA forecast with proper CI
plt.plot(sarima_pred_mean_hc_detrended_test,
         label=f'SARIMA Forecast',
         linestyle='--',
         linewidth=2,
         color="#0cc503")
plt.fill_between(sarima_pred_mean_hc_detrended_test.index,
                sarima_pred_mean_hc_detrended_test - 1.96*sarima_std_detrended,
                sarima_pred_mean_hc_detrended_test + 1.96*sarima_std_detrended,
                color='#0cc503', alpha=0.2)



# Calculate and plot hybrid forecast with combined CI
hybrid_mean = sarima_pred_mean_hc_detrended_test + predictions_df_hc_detrended_residuals_sarima_lstm['Predictions']
hybrid_std = np.sqrt(sarima_std_detrended**2 + lstm_std**2)  # Combined uncertainty

plt.plot(hybrid_mean,
         label=f'Hybrid SARIMA-LSTM Forecast',
         linestyle='--',
         linewidth=2,
         color="#b326c8")
plt.fill_between(hybrid_mean.index,
                 hybrid_mean - 1.96*hybrid_std,
                 hybrid_mean + 1.96*hybrid_std,
                 color='#b326c8', alpha=0.2)

plt.title('Very Hungry Caterpillar: Hybrid Model Performance', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=10, bbox_to_anchor=(1.02, 1))
plt.grid(False)



plt.tight_layout()
plt.show()

# %% [markdown]
# Based on MAE scores, the best forecast is produced by the LSTM model run on the residuals of the Sarima model from the detrended data, which is slightly better than the Sarima model itself (MAE for LSTM on residuals vs Sarima model: 372.5, and 374.88 respectively).
#
# The hybrid model combining SARIMA and LSTM residuals for detrended data has the same MAE score than the LSTM model itself, but the MAPE score was slightly lower, indicating that the hybrid model has the best performance.
#
# Even though, the improvement for the hybrid model is very small, the amount of work needed to implement the hybrid model is negligible compared to the work needed to implement the LSTM model on the residuals of the sarima model. Therefore the hybrid model seems a perfectly good option. However, it is important to consider that the confidence intervals for the hybrid model are much wider than the ones for the Sarima model, indicating that the hybrid model is less certain about its predictions. This is likely due to the fact that the hybrid model combines two different models, which can lead to increased uncertainty in the predictions.

# %% [markdown]
# ### Modeling Alchemist: Sequential Combination of SARIMA and LSTM
#
# Alquemist data was not detrended, so there will be only one set of analysis for this dataset.

# %%
# Use Best Sarima model for hungry caterpillar: Based on previous analysis, Model 5 had the same performance than best autoarima model: ARIMA(1,0,0)(1,0,1)[52]

# Fit SARIMA model with optimized parameters
sarima_model_alchemist = SARIMAX(ts_train_alchemist, 
                                  order=(2,0,0),
                seasonal_order=(1,0,1,52))

sarima_fit_alchemist = sarima_model_alchemist.fit(disp=False)

# Get predictions for TRAIN SET only 
sarima_pred_alchemist_train = sarima_fit_alchemist.get_prediction(
    start=ts_train_alchemist.index[0], 
    end=ts_train_alchemist.index[-1]
)
sarima_pred_mean_alchemist_train = sarima_pred_alchemist_train.predicted_mean
sarima_pred_conf_int_alchemist_train = sarima_pred_alchemist_train.conf_int()

# Get predictions for TEST SET only 
sarima_pred_alchemist_test = sarima_fit_alchemist.get_prediction(
    start=ts_test_alchemist.index[0], 
    end=ts_test_alchemist.index[-1]
)
sarima_pred_mean_alchemist_test = sarima_pred_alchemist_test.predicted_mean
sarima_pred_conf_int_alchemist_test = sarima_pred_alchemist_test.conf_int()

# Get predictions for FULL DATASET
sarima_pred_full_alchemist = sarima_fit_alchemist.get_prediction(
    start=alchemist.index[0],
    end=alchemist.index[-1]
)
sarima_pred_mean_full_alchemist = sarima_pred_full_alchemist.predicted_mean
sarima_pred_conf_int_full_alchemist = sarima_pred_full_alchemist.conf_int()

# Calculate residuals for Full SET
sarima_full_residuals_alchemist = alchemist - sarima_pred_mean_full_alchemist

# %%
# Use ADF test to make sure residuals from full set have no remaining seasonality/trend
adf_result_alchemist_sarima = adfuller(sarima_full_residuals_alchemist.dropna())
print(f"ADF p-value: {adf_result_alchemist_sarima[1]:.4f}")  # Should be < 0.05. If p > 0.05, consider refining SARIMA further (e.g., adding differencing or seasonal terms).
# Out:
# ADF p-value: 0.0000

# %%
# Plotting
plt.figure(figsize=(18, 8))  # Slightly taller for better spacing
training_start_date = '2020-01-01'

# 1. Main plot with data and forecast
plt.subplot(2, 1, 1)
# Fixed the incorrect comparison in this line:
plt.plot(ts_train_alchemist[ts_train_alchemist.index >= training_start_date],
         label='Training Raw Data', color='black', linewidth=2)
plt.plot(ts_test_alchemist[ts_test_alchemist.index >= training_start_date],
         label='Test Raw Data', color='black', linewidth=2, linestyle=':')


# Plot RAW SARIMA results
plt.plot(sarima_pred_mean_alchemist_train[sarima_pred_mean_alchemist_train.index >= training_start_date],
         label='SARIMA Model Fit (Raw)', color="#d30eff", linewidth=2, linestyle=':')
plt.plot(sarima_pred_mean_alchemist_test,
         label='Forecast (Raw)',
         linestyle='-',
         linewidth=2,
         color="#ff7f0e")
plt.fill_between(sarima_pred_conf_int_alchemist_test.index,
                sarima_pred_conf_int_alchemist_test.iloc[:, 0],
                sarima_pred_conf_int_alchemist_test.iloc[:, 1],
                color='#ff7f0e', alpha=0.1)

plt.title('The Alchemist: SARIMA Model', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))  # Moved legend outside
plt.grid(False)

# 2. Residuals plot
plt.subplot(2, 1, 2)
plt.plot(sarima_full_residuals_alchemist[sarima_full_residuals_alchemist.index >= training_start_date],
         label='Residuals (Detrended)', color="#ff7f0e", linewidth=2)

plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.title('Model Residuals', fontsize=14)
plt.ylabel('Residual Value', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
plt.grid(False)

# Residual metrics annotations

residual_metrics_raw = (f"Residuals RAW :\n"
                       f"Mean: {sarima_full_residuals_alchemist.mean():.2f}\n"
                       f"Std Dev: {sarima_full_residuals_alchemist.std():.2f}\n"
                       f"ADF p-value: {adf_result_alchemist_sarima[1]:.4f}")

plt.annotate(residual_metrics_raw, xy=(0.01, 0.75), xycoords='axes fraction',
             bbox=dict(boxstyle="round", fc="white", ec="#ff7f0e", alpha=0.8),
             fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# Note: Here we modeled only the raw data, unlike the previous case with the hungry caterpillar data where we used detrended and raw data.
# The Alchemist data did not need differencing and the analysis were conducted on the raw time series.

# %% [markdown]
# ### Run the LSTM model on the residuals of the SARIMA model for the Alchemist

# %%
# Define train and test sets for the residuals from detrended SARIMA model
ts_train_alchemist_residuals_sarima = sarima_full_residuals_alchemist[:-32]
ts_test_alchemist_residuals_sarima = sarima_full_residuals_alchemist[-32:]

# %%
# Run LSTM forecaster on the residuals of the Sarima model without any additional preprocessing
forecaster_alchemist_residuals_sarima_lstm_model, predictions_df_alchemist_residuals_sarima_lstm, history_alchemist_residuals_sarima_lstm = run_lstm_forecast(
    ts_train=ts_train_alchemist_residuals_sarima,
    ts_test=ts_test_alchemist_residuals_sarima,
    lookback=52,
    forecast=32,
    epochs=100,
    architecture='simple'  # Use the working architecture
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Training sequences: X_train (540, 52, 1), y_train (540, 32)
# Test sequences: X_test (1, 52, 1)
# Using simple architecture
# Epoch 1/100
# 27/27 [==============================] - 2s 42ms/step - loss: 0.0644 - mae: 0.1989 - val_loss: 0.0130 - val_mae: 0.0802
# Epoch 2/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0196 - mae: 0.1050 - val_loss: 0.0127 - val_mae: 0.0792
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0169 - mae: 0.0964 - val_loss: 0.0121 - val_mae: 0.0752
# Epoch 4/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0152 - mae: 0.0903 - val_loss: 0.0115 - val_mae: 0.0724
# Epoch 5/100
# ...

# %%
# Ensure predictions are aligned with test data timestamps
def align_predictions_with_test(predictions_df, test_series):
    """Align predictions DataFrame index with test series index"""
    # Convert predictions to Series if needed
    if isinstance(predictions_df, pd.DataFrame):
        predictions_series = predictions_df['Predictions']
    else:
        predictions_series = predictions_df
        
    # Find overlapping period
    common_index = test_series.index.intersection(predictions_series.index)
    
    if len(common_index) == 0:
        raise ValueError("No overlapping dates between predictions and test data")
        
    return test_series.loc[common_index], predictions_series.loc[common_index]

# Calculate metrics for each model
def calculate_model_metrics(test_data, predictions, model_name):
    """Calculate and format metrics for a single model"""
    try:
        # Align predictions with test data
        y_true, y_pred = align_predictions_with_test(predictions, test_data)
        
        mae = mean_absolute_error(y_true, y_pred)
        mape = mean_absolute_percentage_error(y_true, y_pred)
        
        return f"{model_name}: MAE={mae:.2f}, MAPE={mape:.2%}"
    except Exception as e:
        return f"{model_name}: Error calculating metrics - {str(e)}"


# Calculate metric for Hybrid Model
hybrid_forecast_test_alchemist_raw = (sarima_pred_mean_alchemist_test + predictions_df_alchemist_residuals_sarima_lstm['Predictions'])

# Calculate metrics for all models
metrics_lstm_residuals_alchemist = "\n".join([
    calculate_model_metrics(ts_test_alchemist_residuals_sarima, predictions_df_alchemist_residuals_sarima_lstm, "LSTM Residuals Model The Alchemist (Raw)"),
    calculate_model_metrics(ts_test_alchemist, sarima_pred_mean_alchemist_test, "Sarima Model The Alchemist (RAW)"),
    calculate_model_metrics(ts_test_alchemist, hybrid_forecast_test_alchemist_raw, "Hybrid Model The Alchemist (RAW)")
])
print("Metrics for LSTM Residuals Models The Alchemist:")
print(metrics_lstm_residuals_alchemist)
# Out:
# Metrics for LSTM Residuals Models The Alchemist:
# LSTM Residuals Model The Alchemist (Raw): MAE=144.46, MAPE=105.23%
# Sarima Model The Alchemist (RAW): MAE=148.28, MAPE=21.21%
# Hybrid Model The Alchemist (RAW): MAE=144.46, MAPE=21.33%

# %% [markdown]
# #### Calculate mean and standard deviation of the residuals for residual model

# %%
# Calculate Mean and STD of residuals for LSTM model
lstm_validation_residuals_alchemist = predictions_df_alchemist_residuals_sarima_lstm['Predictions'] - ts_test_alchemist_residuals_sarima
lstm_mean_alchemist = np.mean(lstm_validation_residuals_alchemist)
lstm_std_alchemist = np.std(lstm_validation_residuals_alchemist)
print(f"LSTM Residuals Model The Alchemist - Mean: {lstm_mean_alchemist:.2f}, STD: {lstm_std_alchemist:.2f}")

# Calculate Mean and STD of residuals for SARIMA model detrended
sarima_validation_residuals_alchemist = sarima_pred_mean_alchemist_test - ts_test_alchemist
sarima_mean_alchemist = np.mean(sarima_validation_residuals_alchemist)
sarima_std_alchemist = np.std(sarima_validation_residuals_alchemist)
print(f"SARIMA Model The Alchemist - Mean: {sarima_mean_alchemist:.2f}, STD: {sarima_std_alchemist:.2f}")
# Out:
# LSTM Residuals Model The Alchemist - Mean: -85.36, STD: 200.68
# SARIMA Model The Alchemist - Mean: -101.74, STD: 199.91

# %%
plt.figure(figsize=(18, 8))
training_start_date = '2020-01-01'

# 1. Main plot with data and forecast
plt.subplot(2, 1, 1)

# Plot actual data
plt.plot(ts_train_alchemist[ts_train_alchemist.index >= training_start_date],
         label='Training Data (Detrended)', color="#000000", linewidth=2)
plt.plot(ts_test_alchemist[ts_test_alchemist.index >= training_start_date],
         label='Test Data (Detrended)', color="#989898", linewidth=2)

# Plot SARIMA forecast with proper CI
plt.plot(sarima_pred_mean_alchemist_test,
         label=f'SARIMA Forecast',
         linestyle='--',
         linewidth=2,
         color="#0cc503")
plt.fill_between(sarima_pred_mean_alchemist_test.index,
                sarima_pred_mean_alchemist_test - 1.96*sarima_std_alchemist,
                sarima_pred_mean_alchemist_test + 1.96*sarima_std_alchemist,
                color='#0cc503', alpha=0.2)



# Calculate and plot hybrid forecast with combined CI
hybrid_mean_alchemist = sarima_pred_mean_alchemist_test + predictions_df_alchemist_residuals_sarima_lstm['Predictions']
hybrid_std_alchemist = np.sqrt(sarima_std_alchemist**2 + lstm_std_alchemist**2)  # Combined uncertainty

plt.plot(hybrid_mean_alchemist,
         label=f'Hybrid Forecast',
         linestyle='--',
         linewidth=2,
         color="#b326c8")
plt.fill_between(hybrid_mean_alchemist.index,
                 hybrid_mean_alchemist - 1.96*hybrid_std_alchemist,
                 hybrid_mean_alchemist + 1.96*hybrid_std_alchemist,
                 color='#b326c8', alpha=0.2)

plt.title('The Alchemist: Hybrid Model Performance', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=10, bbox_to_anchor=(1.02, 1))
plt.grid(False)



plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 12))  # Taller figure to accommodate all panels
training_start_date = '2020-01-01'
# ===================== Very Hungry Caterpillar =====================
# Panel 1: Main plot
plt.subplot(4, 1, 1)  # 4 rows, 1 columns, position 1
plt.plot(ts_train_hung_caterp_detrended[ts_train_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Training Data', color='black', linewidth=2)
plt.plot(ts_test_hung_caterp_detrended[ts_test_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Test Data', color="#A9A9A9", linewidth=2, linestyle='-')

# Plot processed SARIMA for detrended data
plt.plot(sarima_pred_mean_hc_detrended_test,
         label='Forecast (Detrended)',
         linestyle='-',
         linewidth=2,
         color="#06a218")
plt.fill_between(sarima_pred_conf_int_hc_detrended_test.index,
                sarima_pred_conf_int_hc_detrended_test.iloc[:, 0],
                sarima_pred_conf_int_hc_detrended_test.iloc[:, 1],
                color='#06a218', alpha=0.1)

# Plot hybrid forecast with proper CI
plt.plot(hybrid_mean,
         label=f'Hybrid Forecast (σ={hybrid_std:.2f})',
         linestyle='--',
         linewidth=2,
         color="#ee48ca")
plt.fill_between(hybrid_mean.index,
                 hybrid_mean - 1.96*hybrid_std,
                 hybrid_mean + 1.96*hybrid_std,
                 color='#ee48ca', alpha=0.05)


plt.title('The Very Hungry Caterpillar: Sarima vs Sequential Sarima-LSTM Hybrid Forecast', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=11)  # Moved legend outside
plt.grid(False)

# # Panel 2: Residuals
plt.subplot(4, 1, 2)  # position 2
plt.plot(sarima_full_residuals_hc_detrended[sarima_full_residuals_hc_detrended.index >= training_start_date],
         label='Residuals (Detrended)', color="#06a218", linewidth=2)

plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.title('Residuals Analysis: The Very Hungry Caterpillar', fontsize=16)
plt.ylabel('Residual Value', fontsize=12)
plt.grid(False)

# Residual metrics annotations
residual_metrics_detrended = (f"Residuals Detrended:\n"
                             f"Mean: {sarima_full_residuals_hc_detrended.mean():.2f}\n"
                             f"Std Dev: {sarima_full_residuals_hc_detrended.std():.2f}\n"
                             f"ADF p-value: {adf_result_hc_detrended_sarima[1]:.4f}")

plt.annotate(residual_metrics_detrended, xy=(0.007, 0.65), xycoords='axes fraction',
             bbox=dict(boxstyle="round", fc="white", ec="#464646", alpha=0.8),
             fontsize=11)

# ===================== The Alchemist =====================
# Panel 3: Main plot
plt.subplot(4, 1, 3)  # position 3
plt.plot(ts_train_alchemist[ts_train_alchemist.index >= training_start_date],
         label='Training Data (Raw)', color='black', linewidth=2)
plt.plot(ts_test_alchemist[ts_test_alchemist.index >= training_start_date],
         label='Test Data (Raw)', color='#A9A9A9', linewidth=2, linestyle='--')

plt.plot(sarima_pred_mean_alchemist_test,
         label='SARIMA Forecast (Raw)',
         linestyle='-',
         linewidth=2,
         color="#06a218")
plt.fill_between(sarima_pred_conf_int_alchemist_test.index,
                sarima_pred_conf_int_alchemist_test.iloc[:, 0],
                sarima_pred_conf_int_alchemist_test.iloc[:, 1],
                color='#06a218', alpha=0.1)

# Plot hybrid forecast with proper CI
plt.plot(hybrid_mean_alchemist,
         label=f'Hybrid Forecast (σ={hybrid_std_alchemist:.2f})',
         linestyle='--',
         linewidth=2,
         color="#ee48ca")
plt.fill_between(hybrid_mean_alchemist.index,
                 hybrid_mean_alchemist - 1.96*hybrid_std_alchemist,
                 hybrid_mean_alchemist + 1.96*hybrid_std_alchemist,
                 color='#ee48ca', alpha=0.05)

plt.title('The Alchemist: Sarima vs Sequential Sarima-LSTM Hybrid Forecast', fontsize=18)
plt.ylabel('Weekly Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=11) 
plt.grid(False)

# # Panel 4: Residuals
plt.subplot(4, 1, 4)  # position 4
plt.plot(sarima_full_residuals_alchemist[sarima_full_residuals_alchemist.index >= training_start_date],
         label='Residuals (Raw)', color="#06a218", linewidth=2)
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.title('Residuals Analysis The Alchemist', fontsize=14)
plt.ylabel('Residual Value', fontsize=12)
plt.grid(False)

# Residual metrics annotation
residual_metrics_al = (f"SARIMA Residuals (Raw):\n"
                      f"Mean: {sarima_full_residuals_alchemist.mean():.2f}\n"
                      f"Std Dev: {sarima_full_residuals_alchemist.std():.2f}\n"
                      f"ADF p-value: {adf_result_alchemist_sarima[1]:.4f}")
plt.annotate(residual_metrics_al, xy=(0.007, 0.65), xycoords='axes fraction',
             bbox=dict(boxstyle="round", fc="white", ec="#595959", alpha=0.8),
             fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# No major improvements were observed in the forecasting accuracy after applying the hybrid model. This indicates that the Sarima models were capable of capturing most of the underlying patterns in the data, and since the LSTM modeling was applied to the residuals, there was little information that the models could capture.
#
# This is a common outcome when the time series has strong seasonal and trend components that SARIMA handles well. The data doesn't have complex nonlinear patterns that would benefit from neural network approaches. The dataset size is moderate (LSTMs typically need substantial data to outperform simpler models).
#
# It is important to consider that the lack of improvement could also stem from suboptimal LSTM architecture, insufficient training data, or poor hyperparameter tuning rather than fundamental model limitations. These elements were not explored in detail due to time constraints.
#
# The hybrid models could benefit from alternative strategies, such as parallel modeling rather than sequential modeling.

# %%
plt.figure(figsize=(18, 8))  # Taller figure to accommodate all panels
training_start_date = '2022-01-01'
# ===================== Very Hungry Caterpillar =====================
# Panel 1: Main plot
plt.subplot(2, 1, 1)  # 2 rows, 1 columns, position 1
plt.plot(ts_train_hung_caterp_detrended[ts_train_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Training Data', color='black', linewidth=3)
plt.plot(ts_test_hung_caterp_detrended[ts_test_hung_caterp_detrended.index >= training_start_date],
         label='Detrended Test Data', color="#A9A9A9", linewidth=3, linestyle='-')

# Plot hybrid forecast with proper CI
plt.plot(hybrid_mean,
         label=f'Hybrid Forecast',
         linestyle='--',
         linewidth=3,
         color="#19cf22")
plt.fill_between(hybrid_mean.index,
                 hybrid_mean - 1.96*hybrid_std,
                 hybrid_mean + 1.96*hybrid_std,
                 color='#19cf22', alpha=0.05)


plt.title('The Very Hungry Caterpillar: Sarima vs Sequential Sarima-LSTM Hybrid Forecast', fontsize=18)
plt.ylabel('Weekly Book Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=11)  # Moved legend outside
plt.grid(False)


# ===================== The Alchemist =====================
# Panel 3: Main plot
plt.subplot(2, 1, 2)  # position 2
plt.plot(ts_train_alchemist[ts_train_alchemist.index >= training_start_date],
         label='Training Data (Raw)', color='black', linewidth=3)
plt.plot(ts_test_alchemist[ts_test_alchemist.index >= training_start_date],
         label='Test Data (Raw)', color='#A9A9A9', linewidth=3, linestyle='-')

# Plot hybrid forecast with proper CI
plt.plot(hybrid_mean_alchemist,
         label=f'Hybrid Forecast',
         linestyle='--',
         linewidth=3,
         color="#ee48ca")
plt.fill_between(hybrid_mean_alchemist.index,
                 hybrid_mean_alchemist - 1.96*hybrid_std_alchemist,
                 hybrid_mean_alchemist + 1.96*hybrid_std_alchemist,
                 color='#ee48ca', alpha=0.05)

plt.title('The Alchemist: Sarima vs Sequential Sarima-LSTM Hybrid Forecast', fontsize=18)
plt.ylabel('Weekly Sales', fontsize=12)
plt.legend(loc='upper left', fontsize=11) 
plt.grid(False)

plt.tight_layout()
plt.show()
